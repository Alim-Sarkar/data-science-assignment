# %%
# importing the labraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Feature transformation: change

df = pd.read_csv("supershops.csv")
df
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %% [markdown]
# # normalization(0,1)

# %%
from sklearn.preprocessing import MinMaxScaler # feature r opre normalization hobe sobar opre na. 
m = MinMaxScaler() #  y r opre hobe na.# feature range=0,1,2,5....

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
df_mar = m.fit_transform(df[['Marketing Spend']]) # training korlam 
df_mar
# Out:
# array([[0.69261666],
#        [0.98335946],
#        [0.92798459],
#        [0.87313643],
#        [0.85943772],
#        [0.797566  ],
#        [0.81412828],
#        [0.7880179 ],
#        [0.72901786],
#        [0.74590551],
#        [0.61635061],
#        [0.60884455],
#        [0.56766982],
#        [0.55635219],
#        [0.72539353],
#        [1.        ],
#        [0.47180821],
#        [0.57246821],
#        [0.55488118],
#        [0.52264964],
#        [0.46116861],
#        [0.47408436],
#        [0.4475048 ],
#        [0.40842369],
#        [0.46594728],
#        [0.39107967],
#        [0.45557444],
#        [0.43609283],
#        [0.39946683],
#        [0.39676926],
#        [0.37493063],
#        [0.36974101],
#        [0.38348453],
#        [0.33561668],
#        [0.2807759 ],
#        [0.2782839 ],
#        [0.17335288],
#        [0.26652654],
#        [0.12234465],
#        [0.23319442],
#        [0.17390063],
#        [0.16869099],
#        [0.14297577],
# ...

# %%
df_mar
# Out:
# MinMaxScaler()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df[['Marketing Spend']] = m.transform(df[['Marketing Spend']]) # choto data te transform korlam

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
# fit and transform both 
df[['Administration']] = m.fit_transform(df[['Administration']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.651744  471784.10    Dhaka  192261.83
# 1         0.983359        0.761972  443898.53      Ctg  191792.06
# 2         0.927985        0.379579  407934.54  Rangpur  191050.39
# 3         0.873136        0.512998  383199.62    Dhaka  182901.99
# 4         0.859438        0.305328  366168.42  Rangpur  166187.94

# %%
x = df.drop('Profit', axis=1)
y = df[['Profit']]

# %% [markdown]
# # Min Max Scaler using for loop

# %%
x1 = x.copy()
x2 = x.copy()
x3 = x.copy()
x4 = x.copy()
x5 = x.copy()
x6 = x.copy()

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.692617        0.651744   1.000000    Dhaka
# 1         0.983359        0.761972   0.940893      Ctg
# 2         0.927985        0.379579   0.864664  Rangpur
# 3         0.873136        0.512998   0.812235    Dhaka
# 4         0.859438        0.305328   0.776136  Rangpur

# %%
scaler = MinMaxScaler()

for col in x.columns:
    if pd.api.types.is_numeric_dtype(x[col]):
        x[col] = scaler.fit_transform(x[[col]])
        continue

print(x.head())
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.692617        0.651744   1.000000    Dhaka
# 1         0.983359        0.761972   0.940893      Ctg
# 2         0.927985        0.379579   0.864664  Rangpur
# 3         0.873136        0.512998   0.812235    Dhaka
# 4         0.859438        0.305328   0.776136  Rangpur

# %% [markdown]
# # Standard Scaler

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

# %%
from sklearn.preprocessing import StandardScaler
s = StandardScaler()

# %%
df_mar = s.fit(df[['Marketing Spend']])

# %%
df_mar
# Out:
# StandardScaler()

# %%
df_mar = s.fit(df[['Marketing Spend']]) # trainging

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.651744   1.000000    Dhaka  1.000000
# 1         0.983359        0.761972   0.940893      Ctg  0.997355
# 2         0.927985        0.379579   0.864664  Rangpur  0.993178
# 3         0.873136        0.512998   0.812235    Dhaka  0.947292
# 4         0.859438        0.305328   0.776136  Rangpur  0.853171

# %%
df[['Marketing Spend']] = s.fit_transform(df[['Marketing Spend']]) #fit_transform both

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.897913        0.651744   1.000000    Dhaka  1.000000
# 1         1.955860        0.761972   0.940893      Ctg  0.997355
# 2         1.754364        0.379579   0.864664  Rangpur  0.993178
# 3         1.554784        0.512998   0.812235    Dhaka  0.947292
# 4         1.504937        0.305328   0.776136  Rangpur  0.853171

# %%
#using for loop

# %%
x1 = x.copy()

# %%
scaler = StandardScaler()

for col in x1.columns:
    if pd.api.types.is_numeric_dtype(x1[col]):
        x1[col] = scaler.fit_transform(x1[[col]])
        continue

print(x1.head())
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.897913        0.560753   2.165287    Dhaka
# 1         1.955860        1.082807   1.929843      Ctg
# 2         1.754364       -0.728257   1.626191  Rangpur
# 3         1.554784       -0.096365   1.417348    Dhaka
# 4         1.504937       -1.079919   1.273550  Rangpur

# %% [markdown]
# # Max abs scaler

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MaxAbsScaler.html

# %%
from sklearn.preprocessing import MaxAbsScaler
mx = MaxAbsScaler()

# %%
df_mar = mx.fit(df[['Marketing Spend']])

# %%
df_mar
# Out:
# MaxAbsScaler()

# %%
df[['Marketing Spend']] = mx.fit_transform(df[['Marketing Spend']]) # fit and transfer both

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.445303        0.651744   1.000000    Dhaka  1.000000
# 1         0.969971        0.761972   0.940893      Ctg  0.997355
# 2         0.870043        0.379579   0.864664  Rangpur  0.993178
# 3         0.771065        0.512998   0.812235    Dhaka  0.947292
# 4         0.746344        0.305328   0.776136  Rangpur  0.853171

# %% [markdown]
# # using for loop

# %%
x2 = x.copy()

# %%
x2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.692617        0.651744   1.000000    Dhaka
# 1         0.983359        0.761972   0.940893      Ctg
# 2         0.927985        0.379579   0.864664  Rangpur
# 3         0.873136        0.512998   0.812235    Dhaka
# 4         0.859438        0.305328   0.776136  Rangpur

# %%
scaler = StandardScaler()

for col in x2.columns:
    if pd.api.types.is_numeric_dtype(x2[col]):
        x2[col] = scaler.fit_transform(x2[[col]])
        continue

print(x2.head())
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.897913        0.560753   2.165287    Dhaka
# 1         1.955860        1.082807   1.929843      Ctg
# 2         1.754364       -0.728257   1.626191  Rangpur
# 3         1.554784       -0.096365   1.417348    Dhaka
# 4         1.504937       -1.079919   1.273550  Rangpur

# %% [markdown]
# # Robust Scaler

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html

# %%
from sklearn.preprocessing import RobustScaler
R =  RobustScaler()

# %%
df_mar = R.fit_transform(df[['Marketing Spend']])

# %%
df_mar
# Out:
# array([[ 0.67253009],
#        [ 1.45211292],
#        [ 1.3036336 ],
#        [ 1.15656655],
#        [ 1.11983554],
#        [ 0.95393588],
#        [ 0.99834513],
#        [ 0.9283341 ],
#        [ 0.77013442],
#        [ 0.8154161 ],
#        [ 0.46803423],
#        [ 0.44790788],
#        [ 0.33750405],
#        [ 0.30715756],
#        [ 0.76041632],
#        [ 1.49673201],
#        [ 0.08046566],
#        [ 0.35037021],
#        [ 0.30321327],
#        [ 0.21678926],
#        [ 0.05193717],
#        [ 0.08656882],
#        [ 0.01529973],
#        [-0.08949034],
#        [ 0.06475046],
#        [-0.13599571],
#        [ 0.03693728],
#        [-0.01529973],
#        [-0.11350681],
#        [-0.12073992],
#        [-0.1792969 ],
#        [-0.19321209],
#        [-0.15636092],
#        [-0.28471131],
#        [-0.43175858],
#        [-0.43844049],
#        [-0.71979714],
#        [-0.46996607],
#        [-0.85656799],
#        [-0.55934112],
#        [-0.71832843],
# ...

# %%
df[['Marketing Spend']] = R.fit_transform(df[['Marketing Spend']]) # fit and transfer both

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.672530        0.651744   1.000000    Dhaka  1.000000
# 1         1.452113        0.761972   0.940893      Ctg  0.997355
# 2         1.303634        0.379579   0.864664  Rangpur  0.993178
# 3         1.156567        0.512998   0.812235    Dhaka  0.947292
# 4         1.119836        0.305328   0.776136  Rangpur  0.853171

# %% [markdown]
# # using for loop

# %%
x3.copy()
x3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.692617        0.651744   1.000000    Dhaka
# 1         0.983359        0.761972   0.940893      Ctg
# 2         0.927985        0.379579   0.864664  Rangpur
# 3         0.873136        0.512998   0.812235    Dhaka
# 4         0.859438        0.305328   0.776136  Rangpur

# %%
scaler = RobustScaler()

for col in x3.columns:
    if pd.api.types.is_numeric_dtype(x3[col]):
        x3[col] = scaler.fit_transform(x3[[col]])
        continue

print(x3.head())
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.672530        0.345355   1.552016    Dhaka
# 1         1.452113        0.697565   1.383714      Ctg
# 2         1.303634       -0.524290   1.166654  Rangpur
# 3         1.156567       -0.097977   1.017368    Dhaka
# 4         1.119836       -0.761543   0.914576  Rangpur

# %% [markdown]
# # extra work

# %%
df.info() # object holo area
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Marketing Spend  50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Transport        49 non-null     float64
#  3   Area             50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df[['Transport']] = m.fit_transform(df[['Transport']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.651744   1.000000    Dhaka  192261.83
# 1         0.983359        0.761972   0.940893      Ctg  191792.06
# 2         0.927985        0.379579   0.864664  Rangpur  191050.39
# 3         0.873136        0.512998   0.812235    Dhaka  182901.99
# 4         0.859438        0.305328   0.776136  Rangpur  166187.94

# %%
x = df.iloc[:,0:3] # jei feature golu nia kaj korbo tar list
# iloc()select a specific row or column from the data set.

# %%
x
# Out:
#     Marketing Spend  Administration  Transport
# 0          0.692617        0.651744   1.000000
# 1          0.983359        0.761972   0.940893
# 2          0.927985        0.379579   0.864664
# 3          0.873136        0.512998   0.812235
# 4          0.859438        0.305328   0.776136
# 5          0.797566        0.369448   0.769126
# 6          0.814128        0.730161   0.270710
# 7          0.788018        0.717457   0.686493
# 8          0.729018        0.741733   0.660500
# 9          0.745906        0.436929   0.646443
# 10         0.616351        0.451506   0.485733
# 11         0.608845        0.308364   0.529362
# 12         0.567670        0.578836   0.529563
# 13         0.556352        0.641066   0.535552
# 14         0.725394        0.801327   0.543708
# 15         1.000000        0.543030   0.554864
# 16         0.471808        0.535270   0.560312
# 17         0.572468        0.714013   0.598948
# 18         0.554881        0.478772   0.625116
# ...

# %%
from sklearn.preprocessing import MinMaxScaler # feature r opre normalization hobe sobar opre na. 
m = MinMaxScaler(feature_range=(0,1))

# %%
x_after_min_max_scaler = m.fit_transform(x)

# %%
x_after_min_max_scaler      # minimum value 0 te convert korse r maximum  value k convert korse 1 .
# Out:
# array([[0.69261666, 0.65174393, 1.        ],
#        [0.98335946, 0.76197173, 0.94089337],
#        [0.92798459, 0.37957895, 0.8646636 ],
#        [0.87313643, 0.51299839, 0.81223513],
#        [0.85943772, 0.30532804, 0.77613557],
#        [0.797566  , 0.3694479 , 0.76912588],
#        [0.81412828, 0.73016111, 0.27071031],
#        [0.7880179 , 0.71745725, 0.68649342],
#        [0.72901786, 0.74173276, 0.66049977],
#        [0.74590551, 0.43692884, 0.64644319],
#        [0.61635061, 0.45150637, 0.48573267],
#        [0.60884455, 0.30836422, 0.52936195],
#        [0.56766982, 0.57883556, 0.52956308],
#        [0.55635219, 0.64106561, 0.53555202],
#        [0.72539353, 0.8013272 , 0.54370828],
#        [1.        , 0.54302973, 0.55486446],
#        [0.47180821, 0.53527036, 0.56031151],
#        [0.57246821, 0.71401273, 0.59894835],
#        [0.55488118, 0.47877201, 0.62511553],
#        [0.52264964, 0.77823604,        nan],
#        [0.46116861, 0.47642362, 0.63305328],
# ...

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
Standardization = StandardScaler()

# %%
x_after_Standardization = Standardization .fit_transform(x)

# %%
x_after_Standardization # -1 to 1 r majje asbe value
# Out:
# array([[ 0.89791312,  0.56075291,  2.1652875 ],
#        [ 1.95586034,  1.08280658,  1.92984309],
#        [ 1.75436374, -0.72825703,  1.62619068],
#        [ 1.55478369, -0.09636463,  1.41734795],
#        [ 1.5049372 , -1.07991935,  1.27354954],
#        [ 1.27980001, -0.77623907,  1.24562725],
#        [ 1.34006641,  0.93214721, -0.73975326],
#        [ 1.24505666,  0.87198001,  0.91647045],
#        [ 1.03036886,  0.9869521 ,  0.81292778],
#        [ 1.09181921, -0.45664025,  0.75693503],
#        [ 0.62039825, -0.38759909,  0.11676333],
#        [ 0.59308542, -1.0655396 ,  0.29055549],
#        [ 0.44325987,  0.21544906,  0.29135667],
#        [ 0.4020776 ,  0.51017895,  0.31521294],
#        [ 1.01718075,  1.26919939,  0.34770243],
#        [ 2.01641149,  0.04586785,  0.39214179],
#        [ 0.0944412 ,  0.00911842,  0.41383946],
#        [ 0.46072013,  0.85566632,  0.56774486],
#        [ 0.39672494, -0.25846537,  0.67197878],
#        [ 0.27944165,  1.15983657,         nan],
# ...

# %%
# robust scaler
from sklearn.preprocessing import RobustScaler
robust = RobustScaler()
x_robust = robust.fit_transform(x)

# %%
x_robust # error k minimize choto kore nia asha
# Out:
# array([[ 0.67253009,  0.34535525,  1.55201644],
#        [ 1.45211292,  0.6975647 ,  1.38371396],
#        [ 1.3036336 , -0.52428997,  1.16665443],
#        [ 1.15656655, -0.09797658,  1.0173676 ],
#        [ 1.11983554, -0.76154296,  0.91457633],
#        [ 0.95393588, -0.5566616 ,  0.89461668],
#        [ 0.99834513,  0.59592064, -0.52459079],
#        [ 0.9283341 ,  0.55532815,  0.65932587],
#        [ 0.77013442,  0.63289538,  0.58531056],
#        [ 0.8154161 , -0.34104062,  0.54528533],
#        [ 0.46803423, -0.29446122,  0.08767206],
#        [ 0.44790788, -0.75184149,  0.21190373],
#        [ 0.33750405,  0.11239208,  0.21247644],
#        [ 0.30715756,  0.31123495,  0.22952959],
#        [ 0.76041632,  0.82331673,  0.25275401],
#        [ 1.49673201, -0.00201781,  0.28452056],
#        [ 0.08046566, -0.02681124,  0.30003068],
#        [ 0.35037021,  0.54432193,  0.41004671],
#        [ 0.30321327, -0.20733968,  0.48455614],
#        [ 0.21678926,  0.74953386,         nan],
# ...

# %%
df[['Profit']] = m.fit_transform(df[['Profit']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.651744   1.000000    Dhaka  1.000000
# 1         0.983359        0.761972   0.940893      Ctg  0.997355
# 2         0.927985        0.379579   0.864664  Rangpur  0.993178
# 3         0.873136        0.512998   0.812235    Dhaka  0.947292
# 4         0.859438        0.305328   0.776136  Rangpur  0.853171

# %%
y = df.iloc[:,-1:5] # independence value r list -y

# %%
y
# Out:
#       Profit
# 0   1.000000
# 1   0.997355
# 2   0.993178
# 3   0.947292
# 4   0.853171
# 5   0.801382
# 6   0.796490
# 7   0.794407
# 8   0.774468
# 9   0.760661
# 10  0.740175
# 11  0.729686
# 12  0.714629
# 13  0.673644
# 14  0.664044
# 15  0.648921
# 16  0.632454
# 17  0.623317
# 18  0.617103
# 19  0.608713
# 20  0.584482
# 21  0.544157
# 22  0.538747
# 23  0.529634
# 24  0.528609
# 25  0.522146
# 26  0.512737
# 27  0.508654
# 28  0.498934
# 29  0.486108
# 30  0.480099
# 31  0.466280
# 32  0.465966
# 33  0.462312
# 34  0.461939
# 35  0.460626
# 36  0.428126
# 37  0.423852
# 38  0.374747
# 39  0.373489
# 40  0.357914
# 41  0.355430
# 42  0.319951
# 43  0.310156
# 44  0.284485
# 45  0.282940
# 46  0.196020
# 47  0.156990
# 48  0.118211
# 49  0.000000

# %%
# normalization(0,1) for dependent value =y
from sklearn.preprocessing import MinMaxScaler # feature r opre normalization hobe sobar opre na. 
m = MinMaxScaler(feature_range=(0,1))

# %%
y_after_min_max_scaler = m.fit_transform(y)

# %%
y_after_min_max_scaler
# Out:
# array([[1.        ],
#        [0.99735461],
#        [0.99317808],
#        [0.94729239],
#        [0.85317138],
#        [0.80138177],
#        [0.79649041],
#        [0.79440736],
#        [0.77446805],
#        [0.7606613 ],
#        [0.74017475],
#        [0.72968626],
#        [0.71462897],
#        [0.67364377],
#        [0.66404417],
#        [0.64892083],
#        [0.63245443],
#        [0.62331739],
#        [0.61710347],
#        [0.60871268],
#        [0.58448237],
#        [0.54415692],
#        [0.53874658],
#        [0.52963376],
#        [0.52860915],
#        [0.52214616],
#        [0.51273747],
#        [0.50865352],
#        [0.49893437],
#        [0.48610784],
#        [0.48009902],
#        [0.46627976],
#        [0.46596599],
#        [0.46231175],
#        [0.46193942],
#        [0.4606257 ],
#        [0.42812595],
#        [0.42385155],
#        [0.37474659],
#        [0.37348913],
#        [0.35791393],
#        [0.3554301 ],
#        [0.3199513 ],
# ...
